# %%
import os
import json
import numpy as np
import pandas as pd
from scipy.stats import wasserstein_distance
import helpers as ph
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import dataframe_image as dfi

sns.set_style('darkgrid')
# Out:
# /Users/carolina.oguchi/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
RESULTS_DIR = f'./data/distributions/'
CONTEXT = 'default'
SAVEFIG = True

# %%
combined_df = []
for context in ['default', 'steer-qa', 'steer-bio', 'steer-portray']:
    
    cdf = pd.read_csv(os.path.join(RESULTS_DIR, f'Pew_American_Trends_Panel_disagreement_500_{context}_combined.csv'))
    cdf['survey'] = 'Pew_American_Trends_Panel_disagreement_500'
    cdf['context'] = context
    if context != 'default':
        cdf = cdf[cdf['group'] == cdf['steer_group']]
    combined_df.append(cdf)
combined_df = pd.concat(combined_df)
combined_df['Source'] = combined_df.apply(lambda x: 'AI21 Labs' if 'j1-' in x['model_name'].lower() else 'OpenAI',
                                          axis=1)

# %% [markdown]
# ## Measure steerability

# %%
KEYS = ['model_name', 'context', 'attribute', 'group', 'group_order', 'model_order']

grouped = combined_df.groupby(KEYS, as_index=False).agg({'WD': np.mean}) \
         .sort_values(by=['context', 'model_order', 'group_order'])
grouped['Rep'] = 1 - grouped['WD']
# Out:
# /var/folders/7w/89ypm2454vb_fhgcjxtqyq_r0000gp/T/ipykernel_8734/2664974887.py:3: FutureWarning: The provided callable <function mean at 0x107d54700> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   grouped = combined_df.groupby(KEYS, as_index=False).agg({'WD': np.mean}) \

# %%
unsteered = grouped[grouped['context'] == 'default'].rename(columns={'WD': 'WD_d',
                                                                     'Rep': 'Rep_d'})
steered = grouped[grouped['context'] != 'default'].sort_values(by='Rep')
steered = steered.groupby([k for k in KEYS if k != 'context'], as_index=False).last()\
                 .rename(columns={'WD': 'WD_s', 'Rep': 'Rep_s'})
result = pd.merge(unsteered, steered, on=[k for k in KEYS if k != 'context'])

# %%
fig, ax = plt.subplots(figsize=(6, 4))
sns.set_style('whitegrid')

for model in ph.MODEL_NAMES.values():
    if model not in set(result['model_name'].values): continue 
    c = result[result['model_name'] == model]
    
    reg = sm.OLS(c['Rep_s'], c['Rep_d'])
    slope = reg.fit().params['Rep_d']

    sns.regplot(data=c, x='Rep_d', y='Rep_s', ax=ax, 
                label=model, 
                line_kws={'linewidth': 3},
                scatter_kws={'s': 14})
    
xx = np.linspace(0.66, 0.9, 10)
plt.legend(loc=4, fontsize=9, ncol=2)
ax.plot(xx, xx, 'k--')
ax.set_xlim([0.68, 0.88])
ax.set_ylim([0.68, 0.88])

plt.xlabel('Default subgroup representativeness', fontsize=12)
plt.ylabel('Steered subgroup representativeness', fontsize=12)
plt.grid(linestyle='-', linewidth=0.5)
#if SAVEFIG: plt.savefig('./figures/steerability.png', bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Steerability by topic

# %%
topic_info = np.load('./data/human_resp/topic_mapping.npy', allow_pickle=True).item()

# %%
combined_df['topic'] = combined_df.apply(lambda x: topic_info[x['question']]['cg'], axis=1)
combined_df = combined_df.explode(['topic'])

# %%
KEYS = ['Source', 'model_name', 'context', 'attribute', 'group', 'group_order', 'model_order', 'topic']

grouped_topic = combined_df.groupby(KEYS, as_index=False).agg({'WD': np.mean}) \
         .sort_values(by=['context', 'model_order', 'group_order'])
grouped_topic['Rep'] = 1 - grouped_topic['WD']
# Out:
# /var/folders/7w/89ypm2454vb_fhgcjxtqyq_r0000gp/T/ipykernel_8734/1678378457.py:3: FutureWarning: The provided callable <function mean at 0x107d54700> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   grouped_topic = combined_df.groupby(KEYS, as_index=False).agg({'WD': np.mean}) \

# %%
steered_topic = grouped_topic[grouped_topic['context'] != 'default'].sort_values(by='Rep')
steered_topic = steered_topic.groupby([k for k in KEYS if k != 'context'], as_index=False).last()\
                 .rename(columns={'WD': 'WD_s', 'Rep': 'Rep_s', 'model_name': ''})

# %%
steered_topic
# Out:
#          Source                   attribute      group  group_order  \
# 0     AI21 Labs         j1-grande   CREGION  Northeast            0
# 1     AI21 Labs         j1-grande   CREGION  Northeast            0
# 2     AI21 Labs         j1-grande   CREGION  Northeast            0
# 3     AI21 Labs         j1-grande   CREGION  Northeast            0
# 4     AI21 Labs         j1-grande   CREGION  Northeast            0
# ...         ...               ...       ...        ...          ...
# 4549     OpenAI  text-davinci-003       SEX       Male            0
# 4550     OpenAI  text-davinci-003       SEX       Male            0
# 4551     OpenAI  text-davinci-003       SEX       Male            0
# 4552     OpenAI  text-davinci-003       SEX       Male            0
# 4553     OpenAI  text-davinci-003       SEX       Male            0
#
#       model_order                                           topic  \
# 0               3                                community health
# 1               3  corporations, banks, technology and automation
# 2               3                                  crime/security
# 3               3                                  discrimination
# 4               3                          economy and inequality
# ...           ...                                             ...
# 4549           11                        relationships and family
# 4550           11                                        religion
# 4551           11                                         science
# 4552           11                      self-perception and values
# 4553           11                                  status in life
#
#             context      WD_s     Rep_s
# 0     steer-portray  0.154932  0.845068
# 1     steer-portray  0.156863  0.843137
# 2     steer-portray  0.197593  0.802407
# 3         steer-bio  0.167536  0.832464
# 4          steer-qa  0.139665  0.860335
# ...             ...       ...       ...
# 4549  steer-portray  0.256376  0.743624
# 4550  steer-portray  0.219925  0.780075
# 4551       steer-qa  0.269328  0.730672
# 4552  steer-portray  0.319784  0.680216
# 4553      steer-bio  0.150262  0.849738
#
# [4554 rows x 10 columns]

# %%
styles = ph.VIS_STYLES

styles[-1]['props'][-1] = (styles[-1]['props'][-1][0], "105%")
for attribute in np.unique(steered_topic['attribute']):
    print(attribute)
    table = pd.pivot_table(steered_topic[steered_topic['attribute'] == attribute], 
                           columns=['Source', ''], 
                       index='group',
                       values='Rep_s', 
                       sort=False)
    table_vis = table.style.background_gradient('Reds', axis=1).set_table_styles(styles)  \
                           .set_properties(**{"font-size":"0.8rem"}).format(precision=3)
    #if SAVEFIG: dfi.export(table_vis, f'./figures/steerability_{attribute}.png')

    display(table_vis)
# Out:
# CREGION
# <style type="text/css">
# #T_bd741 th {
#   width: 90px;
#   font-size: 95%;
#   border-left: 1px solid black;
#   border-bottom: 1px solid black;
#   border-right: 1px solid black;
#   border-top: 1px solid black;
# }
# #T_bd741 td {
#   text-align: center;
#   border-left: 1px solid black;
#   border-bottom: 1px solid black;
#   border-right: 1px solid black;
#   border-top: 1px solid black;
# }
# #T_bd741 th.row_heading {
#   text-align: center;
#   font-size: 100%;
# }
# #T_bd741 th.col_heading {
#   text-align: center;
#   width: 100px;
#   vertical-align: top;
#   transform: translate(0%,10%);
#   font-size: 105%;
# }
# #T_bd741_row0_col0 {
#   background-color: #7a0510;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_bd741_row0_col1 {
#   background-color: #75030f;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_bd741_row0_col2 {
#   background-color: #8e0912;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_bd741_row0_col3 {
#   background-color: #ab1016;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_bd741_row0_col4, #T_bd741_row1_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_bd741_row0_col5 {
#   background-color: #feeae0;
#   color: #000000;
#   font-size: 0.8rem;
# }
# #T_bd741_row0_col6 {
#   background-color: #fdcbb6;
#   color: #000000;
#   font-size: 0.8rem;
# }
# #T_bd741_row0_col7 {
#   background-color: #e83429;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_bd741_row0_col8, #T_bd741_row1_col8 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-size: 0.8rem;
# }
# #T_bd741_row1_col0, #T_bd741_row1_col4 {
#   background-color: #7c0510;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_bd741_row1_col2 {
#   background-color: #8c0912;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_bd741_row1_col3 {
#   background-color: #a91016;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_bd741_row1_col5 {
#   background-color: #fdd5c4;
#   color: #000000;
#   font-size: 0.8rem;
# }
# #T_bd741_row1_col6 {
#   background-color: #fdccb8;
#   color: #000000;
#   font-size: 0.8rem;
# }
# #T_bd741_row1_col7 {
#   background-color: #fc7f5f;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# </style>
# <table id="T_bd741">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Source</th>
#       <th id="T_bd741_level0_col0" class="col_heading level0 col0" colspan="3">AI21 Labs</th>
#       <th id="T_bd741_level0_col3" class="col_heading level0 col3" colspan="6">OpenAI</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" ></th>
#       <th id="T_bd741_level1_col0" class="col_heading level1 col0" >j1-grande</th>
#       <th id="T_bd741_level1_col1" class="col_heading level1 col1" >j1-grande-v2-beta</th>
#       <th id="T_bd741_level1_col2" class="col_heading level1 col2" >j1-jumbo</th>
#       <th id="T_bd741_level1_col3" class="col_heading level1 col3" >ada</th>
#       <th id="T_bd741_level1_col4" class="col_heading level1 col4" >davinci</th>
#       <th id="T_bd741_level1_col5" class="col_heading level1 col5" >text-ada-001</th>
#       <th id="T_bd741_level1_col6" class="col_heading level1 col6" >text-davinci-001</th>
#       <th id="T_bd741_level1_col7" class="col_heading level1 col7" >text-davinci-002</th>
#       <th id="T_bd741_level1_col8" class="col_heading level1 col8" >text-davinci-003</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >group</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bd741_level0_row0" class="row_heading level0 row0" >Northeast</th>
#       <td id="T_bd741_row0_col0" class="data row0 col0" >0.857</td>
#       <td id="T_bd741_row0_col1" class="data row0 col1" >0.858</td>
#       <td id="T_bd741_row0_col2" class="data row0 col2" >0.853</td>
#       <td id="T_bd741_row0_col3" class="data row0 col3" >0.845</td>
#       <td id="T_bd741_row0_col4" class="data row0 col4" >0.862</td>
#       <td id="T_bd741_row0_col5" class="data row0 col5" >0.755</td>
#       <td id="T_bd741_row0_col6" class="data row0 col6" >0.770</td>
#       <td id="T_bd741_row0_col7" class="data row0 col7" >0.821</td>
#       <td id="T_bd741_row0_col8" class="data row0 col8" >0.747</td>
#     </tr>
#     <tr>
#       <th id="T_bd741_level0_row1" class="row_heading level0 row1" >South</th>
#       <td id="T_bd741_row1_col0" class="data row1 col0" >0.872</td>
#       <td id="T_bd741_row1_col1" class="data row1 col1" >0.878</td>
#       <td id="T_bd741_row1_col2" class="data row1 col2" >0.868</td>
#       <td id="T_bd741_row1_col3" class="data row1 col3" >0.860</td>
#       <td id="T_bd741_row1_col4" class="data row1 col4" >0.872</td>
#       <td id="T_bd741_row1_col5" class="data row1 col5" >0.765</td>
#       <td id="T_bd741_row1_col6" class="data row1 col6" >0.769</td>
#       <td id="T_bd741_row1_col7" class="data row1 col7" >0.802</td>
#       <td id="T_bd741_row1_col8" class="data row1 col8" >0.743</td>
#     </tr>
#   </tbody>
# </table>
# EDUCATION
# <style type="text/css">
# #T_36ba9 th {
#   width: 90px;
#   font-size: 95%;
#   border-left: 1px solid black;
#   border-bottom: 1px solid black;
#   border-right: 1px solid black;
#   border-top: 1px solid black;
# }
# #T_36ba9 td {
#   text-align: center;
#   border-left: 1px solid black;
#   border-bottom: 1px solid black;
#   border-right: 1px solid black;
#   border-top: 1px solid black;
# }
# #T_36ba9 th.row_heading {
#   text-align: center;
#   font-size: 100%;
# }
# #T_36ba9 th.col_heading {
#   text-align: center;
#   width: 100px;
#   vertical-align: top;
#   transform: translate(0%,10%);
#   font-size: 105%;
# }
# #T_36ba9_row0_col0 {
#   background-color: #840711;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_36ba9_row0_col1, #T_36ba9_row1_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_36ba9_row0_col2 {
#   background-color: #940b13;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_36ba9_row0_col3 {
#   background-color: #ad1117;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_36ba9_row0_col4 {
#   background-color: #820711;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_36ba9_row0_col5, #T_36ba9_row1_col5 {
#   background-color: #fdd5c4;
#   color: #000000;
#   font-size: 0.8rem;
# }
# #T_36ba9_row0_col6, #T_36ba9_row1_col6 {
#   background-color: #fdcab5;
#   color: #000000;
#   font-size: 0.8rem;
# }
# #T_36ba9_row0_col7 {
#   background-color: #f0402f;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_36ba9_row0_col8, #T_36ba9_row1_col8 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-size: 0.8rem;
# }
# #T_36ba9_row1_col0 {
#   background-color: #6b010e;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_36ba9_row1_col2 {
#   background-color: #73030f;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_36ba9_row1_col3 {
#   background-color: #9d0d14;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_36ba9_row1_col4 {
#   background-color: #79040f;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_36ba9_row1_col7 {
#   background-color: #fb7555;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# </style>
# <table id="T_36ba9">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Source</th>
#       <th id="T_36ba9_level0_col0" class="col_heading level0 col0" colspan="3">AI21 Labs</th>
#       <th id="T_36ba9_level0_col3" class="col_heading level0 col3" colspan="6">OpenAI</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" ></th>
#       <th id="T_36ba9_level1_col0" class="col_heading level1 col0" >j1-grande</th>
#       <th id="T_36ba9_level1_col1" class="col_heading level1 col1" >j1-grande-v2-beta</th>
#       <th id="T_36ba9_level1_col2" class="col_heading level1 col2" >j1-jumbo</th>
#       <th id="T_36ba9_level1_col3" class="col_heading level1 col3" >ada</th>
#       <th id="T_36ba9_level1_col4" class="col_heading level1 col4" >davinci</th>
#       <th id="T_36ba9_level1_col5" class="col_heading level1 col5" >text-ada-001</th>
#       <th id="T_36ba9_level1_col6" class="col_heading level1 col6" >text-davinci-001</th>
#       <th id="T_36ba9_level1_col7" class="col_heading level1 col7" >text-davinci-002</th>
#       <th id="T_36ba9_level1_col8" class="col_heading level1 col8" >text-davinci-003</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >group</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_36ba9_level0_row0" class="row_heading level0 row0" >College graduate/some postgrad</th>
#       <td id="T_36ba9_row0_col0" class="data row0 col0" >0.852</td>
#       <td id="T_36ba9_row0_col1" class="data row0 col1" >0.859</td>
#       <td id="T_36ba9_row0_col2" class="data row0 col2" >0.849</td>
#       <td id="T_36ba9_row0_col3" class="data row0 col3" >0.841</td>
#       <td id="T_36ba9_row0_col4" class="data row0 col4" >0.853</td>
#       <td id="T_36ba9_row0_col5" class="data row0 col5" >0.762</td>
#       <td id="T_36ba9_row0_col6" class="data row0 col6" >0.766</td>
#       <td id="T_36ba9_row0_col7" class="data row0 col7" >0.814</td>
#       <td id="T_36ba9_row0_col8" class="data row0 col8" >0.742</td>
#     </tr>
#     <tr>
#       <th id="T_36ba9_level0_row1" class="row_heading level0 row1" >Less than high school</th>
#       <td id="T_36ba9_row1_col0" class="data row1 col0" >0.881</td>
#       <td id="T_36ba9_row1_col1" class="data row1 col1" >0.882</td>
#       <td id="T_36ba9_row1_col2" class="data row1 col2" >0.879</td>
#       <td id="T_36ba9_row1_col3" class="data row1 col3" >0.866</td>
#       <td id="T_36ba9_row1_col4" class="data row1 col4" >0.877</td>
#       <td id="T_36ba9_row1_col5" class="data row1 col5" >0.757</td>
#       <td id="T_36ba9_row1_col6" class="data row1 col6" >0.763</td>
#       <td id="T_36ba9_row1_col7" class="data row1 col7" >0.803</td>
#       <td id="T_36ba9_row1_col8" class="data row1 col8" >0.733</td>
#     </tr>
#   </tbody>
# </table>
# INCOME
# <style type="text/css">
# #T_21535 th {
#   width: 90px;
#   font-size: 95%;
#   border-left: 1px solid black;
#   border-bottom: 1px solid black;
#   border-right: 1px solid black;
#   border-top: 1px solid black;
# }
# #T_21535 td {
#   text-align: center;
#   border-left: 1px solid black;
#   border-bottom: 1px solid black;
#   border-right: 1px solid black;
#   border-top: 1px solid black;
# }
# #T_21535 th.row_heading {
#   text-align: center;
#   font-size: 100%;
# }
# #T_21535 th.col_heading {
#   text-align: center;
#   width: 100px;
#   vertical-align: top;
#   transform: translate(0%,10%);
#   font-size: 105%;
# }
# #T_21535_row0_col0 {
#   background-color: #73030f;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_21535_row0_col1, #T_21535_row0_col3 {
#   background-color: #9f0e14;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_21535_row0_col2, #T_21535_row1_col0, #T_21535_row1_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_21535_row0_col4 {
#   background-color: #8e0912;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_21535_row0_col5, #T_21535_row0_col6 {
#   background-color: #feeae1;
#   color: #000000;
#   font-size: 0.8rem;
# }
# #T_21535_row0_col7 {
#   background-color: #f34935;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_21535_row0_col8, #T_21535_row1_col8 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-size: 0.8rem;
# }
# #T_21535_row1_col1 {
#   background-color: #7a0510;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_21535_row1_col2 {
#   background-color: #820711;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_21535_row1_col3 {
#   background-color: #920a13;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_21535_row1_col5 {
#   background-color: #fee9df;
#   color: #000000;
#   font-size: 0.8rem;
# }
# #T_21535_row1_col6 {
#   background-color: #fcad90;
#   color: #000000;
#   font-size: 0.8rem;
# }
# #T_21535_row1_col7 {
#   background-color: #fb6c4c;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# </style>
# <table id="T_21535">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Source</th>
#       <th id="T_21535_level0_col0" class="col_heading level0 col0" colspan="3">AI21 Labs</th>
#       <th id="T_21535_level0_col3" class="col_heading level0 col3" colspan="6">OpenAI</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" ></th>
#       <th id="T_21535_level1_col0" class="col_heading level1 col0" >j1-grande</th>
#       <th id="T_21535_level1_col1" class="col_heading level1 col1" >j1-grande-v2-beta</th>
#       <th id="T_21535_level1_col2" class="col_heading level1 col2" >j1-jumbo</th>
#       <th id="T_21535_level1_col3" class="col_heading level1 col3" >ada</th>
#       <th id="T_21535_level1_col4" class="col_heading level1 col4" >davinci</th>
#       <th id="T_21535_level1_col5" class="col_heading level1 col5" >text-ada-001</th>
#       <th id="T_21535_level1_col6" class="col_heading level1 col6" >text-davinci-001</th>
#       <th id="T_21535_level1_col7" class="col_heading level1 col7" >text-davinci-002</th>
#       <th id="T_21535_level1_col8" class="col_heading level1 col8" >text-davinci-003</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >group</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_21535_level0_row0" class="row_heading level0 row0" >$100,000 or more</th>
#       <td id="T_21535_row0_col0" class="data row0 col0" >0.846</td>
#       <td id="T_21535_row0_col1" class="data row0 col1" >0.836</td>
#       <td id="T_21535_row0_col2" class="data row0 col2" >0.849</td>
#       <td id="T_21535_row0_col3" class="data row0 col3" >0.837</td>
#       <td id="T_21535_row0_col4" class="data row0 col4" >0.840</td>
#       <td id="T_21535_row0_col5" class="data row0 col5" >0.747</td>
#       <td id="T_21535_row0_col6" class="data row0 col6" >0.748</td>
#       <td id="T_21535_row0_col7" class="data row0 col7" >0.804</td>
#       <td id="T_21535_row0_col8" class="data row0 col8" >0.740</td>
#     </tr>
#     <tr>
#       <th id="T_21535_level0_row1" class="row_heading level0 row1" >Less than $30,000</th>
#       <td id="T_21535_row1_col0" class="data row1 col0" >0.873</td>
#       <td id="T_21535_row1_col1" class="data row1 col1" >0.867</td>
#       <td id="T_21535_row1_col2" class="data row1 col2" >0.865</td>
#       <td id="T_21535_row1_col3" class="data row1 col3" >0.860</td>
#       <td id="T_21535_row1_col4" class="data row1 col4" >0.873</td>
#       <td id="T_21535_row1_col5" class="data row1 col5" >0.744</td>
#       <td id="T_21535_row1_col6" class="data row1 col6" >0.775</td>
#       <td id="T_21535_row1_col7" class="data row1 col7" >0.803</td>
#       <td id="T_21535_row1_col8" class="data row1 col8" >0.734</td>
#     </tr>
#   </tbody>
# </table>
# POLIDEOLOGY
# <style type="text/css">
# #T_a787e th {
#   width: 90px;
#   font-size: 95%;
#   border-left: 1px solid black;
#   border-bottom: 1px solid black;
#   border-right: 1px solid black;
#   border-top: 1px solid black;
# }
# #T_a787e td {
#   text-align: center;
#   border-left: 1px solid black;
#   border-bottom: 1px solid black;
#   border-right: 1px solid black;
#   border-top: 1px solid black;
# }
# #T_a787e th.row_heading {
#   text-align: center;
#   font-size: 100%;
# }
# #T_a787e th.col_heading {
#   text-align: center;
#   width: 100px;
#   vertical-align: top;
#   transform: translate(0%,10%);
#   font-size: 105%;
# }
# #T_a787e_row0_col0, #T_a787e_row1_col4, #T_a787e_row2_col2 {
#   background-color: #9c0d14;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_a787e_row0_col1, #T_a787e_row1_col1, #T_a787e_row2_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_a787e_row0_col2 {
#   background-color: #a91016;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_a787e_row0_col3 {
#   background-color: #ab1016;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_a787e_row0_col4 {
#   background-color: #840711;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_a787e_row0_col5 {
#   background-color: #fff1ea;
#   color: #000000;
#   font-size: 0.8rem;
# }
# #T_a787e_row0_col6 {
#   background-color: #fee3d6;
#   color: #000000;
#   font-size: 0.8rem;
# }
# #T_a787e_row0_col7 {
#   background-color: #fb7151;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_a787e_row0_col8, #T_a787e_row1_col5, #T_a787e_row2_col8 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-size: 0.8rem;
# }
# #T_a787e_row1_col0, #T_a787e_row2_col4 {
#   background-color: #920a13;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_a787e_row1_col2 {
#   background-color: #bc141a;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_a787e_row1_col3, #T_a787e_row2_col3 {
#   background-color: #b71319;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_a787e_row1_col6, #T_a787e_row2_col6 {
#   background-color: #fcb99f;
#   color: #000000;
#   font-size: 0.8rem;
# }
# #T_a787e_row1_col7 {
#   background-color: #aa1016;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_a787e_row1_col8 {
#   background-color: #fca285;
#   color: #000000;
#   font-size: 0.8rem;
# }
# #T_a787e_row2_col0 {
#   background-color: #8a0812;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_a787e_row2_col5 {
#   background-color: #fdd2bf;
#   color: #000000;
#   font-size: 0.8rem;
# }
# #T_a787e_row2_col7 {
#   background-color: #fc9272;
#   color: #000000;
#   font-size: 0.8rem;
# }
# </style>
# <table id="T_a787e">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Source</th>
#       <th id="T_a787e_level0_col0" class="col_heading level0 col0" colspan="3">AI21 Labs</th>
#       <th id="T_a787e_level0_col3" class="col_heading level0 col3" colspan="6">OpenAI</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" ></th>
#       <th id="T_a787e_level1_col0" class="col_heading level1 col0" >j1-grande</th>
#       <th id="T_a787e_level1_col1" class="col_heading level1 col1" >j1-grande-v2-beta</th>
#       <th id="T_a787e_level1_col2" class="col_heading level1 col2" >j1-jumbo</th>
#       <th id="T_a787e_level1_col3" class="col_heading level1 col3" >ada</th>
#       <th id="T_a787e_level1_col4" class="col_heading level1 col4" >davinci</th>
#       <th id="T_a787e_level1_col5" class="col_heading level1 col5" >text-ada-001</th>
#       <th id="T_a787e_level1_col6" class="col_heading level1 col6" >text-davinci-001</th>
#       <th id="T_a787e_level1_col7" class="col_heading level1 col7" >text-davinci-002</th>
#       <th id="T_a787e_level1_col8" class="col_heading level1 col8" >text-davinci-003</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >group</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a787e_level0_row0" class="row_heading level0 row0" >Conservative</th>
#       <td id="T_a787e_row0_col0" class="data row0 col0" >0.840</td>
#       <td id="T_a787e_row0_col1" class="data row0 col1" >0.851</td>
#       <td id="T_a787e_row0_col2" class="data row0 col2" >0.837</td>
#       <td id="T_a787e_row0_col3" class="data row0 col3" >0.836</td>
#       <td id="T_a787e_row0_col4" class="data row0 col4" >0.845</td>
#       <td id="T_a787e_row0_col5" class="data row0 col5" >0.751</td>
#       <td id="T_a787e_row0_col6" class="data row0 col6" >0.760</td>
#       <td id="T_a787e_row0_col7" class="data row0 col7" >0.798</td>
#       <td id="T_a787e_row0_col8" class="data row0 col8" >0.748</td>
#     </tr>
#     <tr>
#       <th id="T_a787e_level0_row1" class="row_heading level0 row1" >Liberal</th>
#       <td id="T_a787e_row1_col0" class="data row1 col0" >0.829</td>
#       <td id="T_a787e_row1_col1" class="data row1 col1" >0.838</td>
#       <td id="T_a787e_row1_col2" class="data row1 col2" >0.819</td>
#       <td id="T_a787e_row1_col3" class="data row1 col3" >0.820</td>
#       <td id="T_a787e_row1_col4" class="data row1 col4" >0.827</td>
#       <td id="T_a787e_row1_col5" class="data row1 col5" >0.742</td>
#       <td id="T_a787e_row1_col6" class="data row1 col6" >0.767</td>
#       <td id="T_a787e_row1_col7" class="data row1 col7" >0.824</td>
#       <td id="T_a787e_row1_col8" class="data row1 col8" >0.774</td>
#     </tr>
#     <tr>
#       <th id="T_a787e_level0_row2" class="row_heading level0 row2" >Moderate</th>
#       <td id="T_a787e_row2_col0" class="data row2 col0" >0.862</td>
#       <td id="T_a787e_row2_col1" class="data row2 col1" >0.870</td>
#       <td id="T_a787e_row2_col2" class="data row2 col2" >0.857</td>
#       <td id="T_a787e_row2_col3" class="data row2 col3" >0.849</td>
#       <td id="T_a787e_row2_col4" class="data row2 col4" >0.860</td>
#       <td id="T_a787e_row2_col5" class="data row2 col5" >0.775</td>
#       <td id="T_a787e_row2_col6" class="data row2 col6" >0.785</td>
#       <td id="T_a787e_row2_col7" class="data row2 col7" >0.799</td>
#       <td id="T_a787e_row2_col8" class="data row2 col8" >0.755</td>
#     </tr>
#   </tbody>
# </table>
# POLPARTY
# <style type="text/css">
# #T_6d38e th {
#   width: 90px;
#   font-size: 95%;
#   border-left: 1px solid black;
#   border-bottom: 1px solid black;
#   border-right: 1px solid black;
#   border-top: 1px solid black;
# }
# #T_6d38e td {
#   text-align: center;
#   border-left: 1px solid black;
#   border-bottom: 1px solid black;
#   border-right: 1px solid black;
#   border-top: 1px solid black;
# }
# #T_6d38e th.row_heading {
#   text-align: center;
#   font-size: 100%;
# }
# #T_6d38e th.col_heading {
#   text-align: center;
#   width: 100px;
#   vertical-align: top;
#   transform: translate(0%,10%);
#   font-size: 105%;
# }
# #T_6d38e_row0_col0, #T_6d38e_row1_col0 {
#   background-color: #880811;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_6d38e_row0_col1, #T_6d38e_row1_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_6d38e_row0_col2 {
#   background-color: #a91016;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_6d38e_row0_col3 {
#   background-color: #ac1117;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_6d38e_row0_col4 {
#   background-color: #8a0812;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_6d38e_row0_col5, #T_6d38e_row1_col8 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-size: 0.8rem;
# }
# #T_6d38e_row0_col6 {
#   background-color: #fca285;
#   color: #000000;
#   font-size: 0.8rem;
# }
# #T_6d38e_row0_col7 {
#   background-color: #d42121;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_6d38e_row0_col8 {
#   background-color: #fcaf93;
#   color: #000000;
#   font-size: 0.8rem;
# }
# #T_6d38e_row1_col1 {
#   background-color: #be151a;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_6d38e_row1_col2 {
#   background-color: #9d0d14;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_6d38e_row1_col3 {
#   background-color: #a30f15;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_6d38e_row1_col5 {
#   background-color: #fee4d8;
#   color: #000000;
#   font-size: 0.8rem;
# }
# #T_6d38e_row1_col6 {
#   background-color: #fdd0bc;
#   color: #000000;
#   font-size: 0.8rem;
# }
# #T_6d38e_row1_col7 {
#   background-color: #c8171c;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# </style>
# <table id="T_6d38e">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Source</th>
#       <th id="T_6d38e_level0_col0" class="col_heading level0 col0" colspan="3">AI21 Labs</th>
#       <th id="T_6d38e_level0_col3" class="col_heading level0 col3" colspan="6">OpenAI</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" ></th>
#       <th id="T_6d38e_level1_col0" class="col_heading level1 col0" >j1-grande</th>
#       <th id="T_6d38e_level1_col1" class="col_heading level1 col1" >j1-grande-v2-beta</th>
#       <th id="T_6d38e_level1_col2" class="col_heading level1 col2" >j1-jumbo</th>
#       <th id="T_6d38e_level1_col3" class="col_heading level1 col3" >ada</th>
#       <th id="T_6d38e_level1_col4" class="col_heading level1 col4" >davinci</th>
#       <th id="T_6d38e_level1_col5" class="col_heading level1 col5" >text-ada-001</th>
#       <th id="T_6d38e_level1_col6" class="col_heading level1 col6" >text-davinci-001</th>
#       <th id="T_6d38e_level1_col7" class="col_heading level1 col7" >text-davinci-002</th>
#       <th id="T_6d38e_level1_col8" class="col_heading level1 col8" >text-davinci-003</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >group</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6d38e_level0_row0" class="row_heading level0 row0" >Democrat</th>
#       <td id="T_6d38e_row0_col0" class="data row0 col0" >0.840</td>
#       <td id="T_6d38e_row0_col1" class="data row0 col1" >0.848</td>
#       <td id="T_6d38e_row0_col2" class="data row0 col2" >0.832</td>
#       <td id="T_6d38e_row0_col3" class="data row0 col3" >0.831</td>
#       <td id="T_6d38e_row0_col4" class="data row0 col4" >0.840</td>
#       <td id="T_6d38e_row0_col5" class="data row0 col5" >0.736</td>
#       <td id="T_6d38e_row0_col6" class="data row0 col6" >0.772</td>
#       <td id="T_6d38e_row0_col7" class="data row0 col7" >0.816</td>
#       <td id="T_6d38e_row0_col8" class="data row0 col8" >0.768</td>
#     </tr>
#     <tr>
#       <th id="T_6d38e_level0_row1" class="row_heading level0 row1" >Republican</th>
#       <td id="T_6d38e_row1_col0" class="data row1 col0" >0.826</td>
#       <td id="T_6d38e_row1_col1" class="data row1 col1" >0.814</td>
#       <td id="T_6d38e_row1_col2" class="data row1 col2" >0.822</td>
#       <td id="T_6d38e_row1_col3" class="data row1 col3" >0.821</td>
#       <td id="T_6d38e_row1_col4" class="data row1 col4" >0.831</td>
#       <td id="T_6d38e_row1_col5" class="data row1 col5" >0.757</td>
#       <td id="T_6d38e_row1_col6" class="data row1 col6" >0.764</td>
#       <td id="T_6d38e_row1_col7" class="data row1 col7" >0.812</td>
#       <td id="T_6d38e_row1_col8" class="data row1 col8" >0.749</td>
#     </tr>
#   </tbody>
# </table>
# RACE
# <style type="text/css">
# #T_ae192 th {
#   width: 90px;
#   font-size: 95%;
#   border-left: 1px solid black;
#   border-bottom: 1px solid black;
#   border-right: 1px solid black;
#   border-top: 1px solid black;
# }
# #T_ae192 td {
#   text-align: center;
#   border-left: 1px solid black;
#   border-bottom: 1px solid black;
#   border-right: 1px solid black;
#   border-top: 1px solid black;
# }
# #T_ae192 th.row_heading {
#   text-align: center;
#   font-size: 100%;
# }
# #T_ae192 th.col_heading {
#   text-align: center;
#   width: 100px;
#   vertical-align: top;
#   transform: translate(0%,10%);
#   font-size: 105%;
# }
# #T_ae192_row0_col0 {
#   background-color: #920a13;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_ae192_row0_col1, #T_ae192_row1_col1, #T_ae192_row2_col1, #T_ae192_row3_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_ae192_row0_col2 {
#   background-color: #9c0d14;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_ae192_row0_col3, #T_ae192_row2_col3 {
#   background-color: #ac1117;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_ae192_row0_col4, #T_ae192_row1_col2 {
#   background-color: #980c13;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_ae192_row0_col5, #T_ae192_row1_col5, #T_ae192_row2_col5, #T_ae192_row3_col8 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-size: 0.8rem;
# }
# #T_ae192_row0_col6, #T_ae192_row1_col8, #T_ae192_row2_col8 {
#   background-color: #fedecf;
#   color: #000000;
#   font-size: 0.8rem;
# }
# #T_ae192_row0_col7 {
#   background-color: #db2824;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_ae192_row0_col8 {
#   background-color: #fff4ef;
#   color: #000000;
#   font-size: 0.8rem;
# }
# #T_ae192_row1_col0 {
#   background-color: #880811;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_ae192_row1_col3 {
#   background-color: #b81419;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_ae192_row1_col4 {
#   background-color: #8a0812;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_ae192_row1_col6 {
#   background-color: #fdcebb;
#   color: #000000;
#   font-size: 0.8rem;
# }
# #T_ae192_row1_col7 {
#   background-color: #f75b40;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_ae192_row2_col0 {
#   background-color: #8c0912;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_ae192_row2_col2 {
#   background-color: #ab1016;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_ae192_row2_col4, #T_ae192_row3_col1 {
#   background-color: #900a12;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_ae192_row2_col6 {
#   background-color: #fcc1a8;
#   color: #000000;
#   font-size: 0.8rem;
# }
# #T_ae192_row2_col7 {
#   background-color: #e83429;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_ae192_row3_col0 {
#   background-color: #820711;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_ae192_row3_col2 {
#   background-color: #a81016;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_ae192_row3_col3 {
#   background-color: #b61319;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_ae192_row3_col5 {
#   background-color: #ffece4;
#   color: #000000;
#   font-size: 0.8rem;
# }
# #T_ae192_row3_col6 {
#   background-color: #fcbda4;
#   color: #000000;
#   font-size: 0.8rem;
# }
# #T_ae192_row3_col7 {
#   background-color: #f96346;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# </style>
# <table id="T_ae192">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Source</th>
#       <th id="T_ae192_level0_col0" class="col_heading level0 col0" colspan="3">AI21 Labs</th>
#       <th id="T_ae192_level0_col3" class="col_heading level0 col3" colspan="6">OpenAI</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" ></th>
#       <th id="T_ae192_level1_col0" class="col_heading level1 col0" >j1-grande</th>
#       <th id="T_ae192_level1_col1" class="col_heading level1 col1" >j1-grande-v2-beta</th>
#       <th id="T_ae192_level1_col2" class="col_heading level1 col2" >j1-jumbo</th>
#       <th id="T_ae192_level1_col3" class="col_heading level1 col3" >ada</th>
#       <th id="T_ae192_level1_col4" class="col_heading level1 col4" >davinci</th>
#       <th id="T_ae192_level1_col5" class="col_heading level1 col5" >text-ada-001</th>
#       <th id="T_ae192_level1_col6" class="col_heading level1 col6" >text-davinci-001</th>
#       <th id="T_ae192_level1_col7" class="col_heading level1 col7" >text-davinci-002</th>
#       <th id="T_ae192_level1_col8" class="col_heading level1 col8" >text-davinci-003</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >group</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ae192_level0_row0" class="row_heading level0 row0" >Asian</th>
#       <td id="T_ae192_row0_col0" class="data row0 col0" >0.852</td>
#       <td id="T_ae192_row0_col1" class="data row0 col1" >0.861</td>
#       <td id="T_ae192_row0_col2" class="data row0 col2" >0.849</td>
#       <td id="T_ae192_row0_col3" class="data row0 col3" >0.844</td>
#       <td id="T_ae192_row0_col4" class="data row0 col4" >0.850</td>
#       <td id="T_ae192_row0_col5" class="data row0 col5" >0.749</td>
#       <td id="T_ae192_row0_col6" class="data row0 col6" >0.764</td>
#       <td id="T_ae192_row0_col7" class="data row0 col7" >0.827</td>
#       <td id="T_ae192_row0_col8" class="data row0 col8" >0.750</td>
#     </tr>
#     <tr>
#       <th id="T_ae192_level0_row1" class="row_heading level0 row1" >Black</th>
#       <td id="T_ae192_row1_col0" class="data row1 col0" >0.858</td>
#       <td id="T_ae192_row1_col1" class="data row1 col1" >0.867</td>
#       <td id="T_ae192_row1_col2" class="data row1 col2" >0.854</td>
#       <td id="T_ae192_row1_col3" class="data row1 col3" >0.842</td>
#       <td id="T_ae192_row1_col4" class="data row1 col4" >0.857</td>
#       <td id="T_ae192_row1_col5" class="data row1 col5" >0.738</td>
#       <td id="T_ae192_row1_col6" class="data row1 col6" >0.762</td>
#       <td id="T_ae192_row1_col7" class="data row1 col7" >0.808</td>
#       <td id="T_ae192_row1_col8" class="data row1 col8" >0.755</td>
#     </tr>
#     <tr>
#       <th id="T_ae192_level0_row2" class="row_heading level0 row2" >Hispanic</th>
#       <td id="T_ae192_row2_col0" class="data row2 col0" >0.859</td>
#       <td id="T_ae192_row2_col1" class="data row2 col1" >0.869</td>
#       <td id="T_ae192_row2_col2" class="data row2 col2" >0.850</td>
#       <td id="T_ae192_row2_col3" class="data row2 col3" >0.849</td>
#       <td id="T_ae192_row2_col4" class="data row2 col4" >0.857</td>
#       <td id="T_ae192_row2_col5" class="data row2 col5" >0.735</td>
#       <td id="T_ae192_row2_col6" class="data row2 col6" >0.766</td>
#       <td id="T_ae192_row2_col7" class="data row2 col7" >0.822</td>
#       <td id="T_ae192_row2_col8" class="data row2 col8" >0.753</td>
#     </tr>
#     <tr>
#       <th id="T_ae192_level0_row3" class="row_heading level0 row3" >White</th>
#       <td id="T_ae192_row3_col0" class="data row3 col0" >0.856</td>
#       <td id="T_ae192_row3_col1" class="data row3 col1" >0.853</td>
#       <td id="T_ae192_row3_col2" class="data row3 col2" >0.846</td>
#       <td id="T_ae192_row3_col3" class="data row3 col3" >0.841</td>
#       <td id="T_ae192_row3_col4" class="data row3 col4" >0.863</td>
#       <td id="T_ae192_row3_col5" class="data row3 col5" >0.748</td>
#       <td id="T_ae192_row3_col6" class="data row3 col6" >0.771</td>
#       <td id="T_ae192_row3_col7" class="data row3 col7" >0.804</td>
#       <td id="T_ae192_row3_col8" class="data row3 col8" >0.742</td>
#     </tr>
#   </tbody>
# </table>
# RELIG
# <style type="text/css">
# #T_f45a2 th {
#   width: 90px;
#   font-size: 95%;
#   border-left: 1px solid black;
#   border-bottom: 1px solid black;
#   border-right: 1px solid black;
#   border-top: 1px solid black;
# }
# #T_f45a2 td {
#   text-align: center;
#   border-left: 1px solid black;
#   border-bottom: 1px solid black;
#   border-right: 1px solid black;
#   border-top: 1px solid black;
# }
# #T_f45a2 th.row_heading {
#   text-align: center;
#   font-size: 100%;
# }
# #T_f45a2 th.col_heading {
#   text-align: center;
#   width: 100px;
#   vertical-align: top;
#   transform: translate(0%,10%);
#   font-size: 105%;
# }
# #T_f45a2_row0_col0, #T_f45a2_row2_col7 {
#   background-color: #b71319;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_f45a2_row0_col1 {
#   background-color: #8c0912;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_f45a2_row0_col2 {
#   background-color: #d11e1f;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_f45a2_row0_col3 {
#   background-color: #de2b25;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_f45a2_row0_col4 {
#   background-color: #9c0d14;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_f45a2_row0_col5, #T_f45a2_row1_col5, #T_f45a2_row2_col8, #T_f45a2_row3_col5, #T_f45a2_row4_col8 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-size: 0.8rem;
# }
# #T_f45a2_row0_col6, #T_f45a2_row4_col6 {
#   background-color: #fcaf93;
#   color: #000000;
#   font-size: 0.8rem;
# }
# #T_f45a2_row0_col7, #T_f45a2_row1_col1, #T_f45a2_row2_col1, #T_f45a2_row3_col1, #T_f45a2_row4_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_f45a2_row0_col8 {
#   background-color: #fc9474;
#   color: #000000;
#   font-size: 0.8rem;
# }
# #T_f45a2_row1_col0, #T_f45a2_row4_col1 {
#   background-color: #a30f15;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_f45a2_row1_col2 {
#   background-color: #c3161b;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_f45a2_row1_col3 {
#   background-color: #cb181d;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_f45a2_row1_col4 {
#   background-color: #840711;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_f45a2_row1_col6 {
#   background-color: #fcb095;
#   color: #000000;
#   font-size: 0.8rem;
# }
# #T_f45a2_row1_col7 {
#   background-color: #d21f20;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_f45a2_row1_col8 {
#   background-color: #fedfd0;
#   color: #000000;
#   font-size: 0.8rem;
# }
# #T_f45a2_row2_col0 {
#   background-color: #880811;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_f45a2_row2_col2, #T_f45a2_row4_col2 {
#   background-color: #900a12;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_f45a2_row2_col3 {
#   background-color: #980c13;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_f45a2_row2_col4 {
#   background-color: #7e0610;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_f45a2_row2_col5, #T_f45a2_row3_col6 {
#   background-color: #fcc4ad;
#   color: #000000;
#   font-size: 0.8rem;
# }
# #T_f45a2_row2_col6 {
#   background-color: #fcbfa7;
#   color: #000000;
#   font-size: 0.8rem;
# }
# #T_f45a2_row3_col0 {
#   background-color: #8a0812;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_f45a2_row3_col2 {
#   background-color: #b01217;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_f45a2_row3_col3 {
#   background-color: #c5171c;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_f45a2_row3_col4 {
#   background-color: #9f0e14;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_f45a2_row3_col7 {
#   background-color: #f14130;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_f45a2_row3_col8 {
#   background-color: #fdc9b3;
#   color: #000000;
#   font-size: 0.8rem;
# }
# #T_f45a2_row4_col3 {
#   background-color: #b21218;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_f45a2_row4_col4 {
#   background-color: #73030f;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_f45a2_row4_col5 {
#   background-color: #fee3d6;
#   color: #000000;
#   font-size: 0.8rem;
# }
# #T_f45a2_row4_col7 {
#   background-color: #f03d2d;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# </style>
# <table id="T_f45a2">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Source</th>
#       <th id="T_f45a2_level0_col0" class="col_heading level0 col0" colspan="3">AI21 Labs</th>
#       <th id="T_f45a2_level0_col3" class="col_heading level0 col3" colspan="6">OpenAI</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" ></th>
#       <th id="T_f45a2_level1_col0" class="col_heading level1 col0" >j1-grande</th>
#       <th id="T_f45a2_level1_col1" class="col_heading level1 col1" >j1-grande-v2-beta</th>
#       <th id="T_f45a2_level1_col2" class="col_heading level1 col2" >j1-jumbo</th>
#       <th id="T_f45a2_level1_col3" class="col_heading level1 col3" >ada</th>
#       <th id="T_f45a2_level1_col4" class="col_heading level1 col4" >davinci</th>
#       <th id="T_f45a2_level1_col5" class="col_heading level1 col5" >text-ada-001</th>
#       <th id="T_f45a2_level1_col6" class="col_heading level1 col6" >text-davinci-001</th>
#       <th id="T_f45a2_level1_col7" class="col_heading level1 col7" >text-davinci-002</th>
#       <th id="T_f45a2_level1_col8" class="col_heading level1 col8" >text-davinci-003</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >group</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f45a2_level0_row0" class="row_heading level0 row0" >Atheist</th>
#       <td id="T_f45a2_row0_col0" class="data row0 col0" >0.799</td>
#       <td id="T_f45a2_row0_col1" class="data row0 col1" >0.809</td>
#       <td id="T_f45a2_row0_col2" class="data row0 col2" >0.791</td>
#       <td id="T_f45a2_row0_col3" class="data row0 col3" >0.786</td>
#       <td id="T_f45a2_row0_col4" class="data row0 col4" >0.806</td>
#       <td id="T_f45a2_row0_col5" class="data row0 col5" >0.721</td>
#       <td id="T_f45a2_row0_col6" class="data row0 col6" >0.749</td>
#       <td id="T_f45a2_row0_col7" class="data row0 col7" >0.817</td>
#       <td id="T_f45a2_row0_col8" class="data row0 col8" >0.757</td>
#     </tr>
#     <tr>
#       <th id="T_f45a2_level0_row1" class="row_heading level0 row1" >Hindu</th>
#       <td id="T_f45a2_row1_col0" class="data row1 col0" >0.819</td>
#       <td id="T_f45a2_row1_col1" class="data row1 col1" >0.831</td>
#       <td id="T_f45a2_row1_col2" class="data row1 col2" >0.808</td>
#       <td id="T_f45a2_row1_col3" class="data row1 col3" >0.806</td>
#       <td id="T_f45a2_row1_col4" class="data row1 col4" >0.825</td>
#       <td id="T_f45a2_row1_col5" class="data row1 col5" >0.730</td>
#       <td id="T_f45a2_row1_col6" class="data row1 col6" >0.759</td>
#       <td id="T_f45a2_row1_col7" class="data row1 col7" >0.804</td>
#       <td id="T_f45a2_row1_col8" class="data row1 col8" >0.743</td>
#     </tr>
#     <tr>
#       <th id="T_f45a2_level0_row2" class="row_heading level0 row2" >Jewish</th>
#       <td id="T_f45a2_row2_col0" class="data row2 col0" >0.834</td>
#       <td id="T_f45a2_row2_col1" class="data row2 col1" >0.841</td>
#       <td id="T_f45a2_row2_col2" class="data row2 col2" >0.832</td>
#       <td id="T_f45a2_row2_col3" class="data row2 col3" >0.830</td>
#       <td id="T_f45a2_row2_col4" class="data row2 col4" >0.836</td>
#       <td id="T_f45a2_row2_col5" class="data row2 col5" >0.757</td>
#       <td id="T_f45a2_row2_col6" class="data row2 col6" >0.759</td>
#       <td id="T_f45a2_row2_col7" class="data row2 col7" >0.821</td>
#       <td id="T_f45a2_row2_col8" class="data row2 col8" >0.734</td>
#     </tr>
#     <tr>
#       <th id="T_f45a2_level0_row3" class="row_heading level0 row3" >Muslim</th>
#       <td id="T_f45a2_row3_col0" class="data row3 col0" >0.826</td>
#       <td id="T_f45a2_row3_col1" class="data row3 col1" >0.833</td>
#       <td id="T_f45a2_row3_col2" class="data row3 col2" >0.817</td>
#       <td id="T_f45a2_row3_col3" class="data row3 col3" >0.810</td>
#       <td id="T_f45a2_row3_col4" class="data row3 col4" >0.822</td>
#       <td id="T_f45a2_row3_col5" class="data row3 col5" >0.735</td>
#       <td id="T_f45a2_row3_
# SEX
# <style type="text/css">
# #T_bd1d5 th {
#   width: 90px;
#   font-size: 95%;
#   border-left: 1px solid black;
#   border-bottom: 1px solid black;
#   border-right: 1px solid black;
#   border-top: 1px solid black;
# }
# #T_bd1d5 td {
#   text-align: center;
#   border-left: 1px solid black;
#   border-bottom: 1px solid black;
#   border-right: 1px solid black;
#   border-top: 1px solid black;
# }
# #T_bd1d5 th.row_heading {
#   text-align: center;
#   font-size: 100%;
# }
# #T_bd1d5 th.col_heading {
#   text-align: center;
#   width: 100px;
#   vertical-align: top;
#   transform: translate(0%,10%);
#   font-size: 105%;
# }
# #T_bd1d5_row0_col0, #T_bd1d5_row1_col0 {
#   background-color: #6f020e;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_bd1d5_row0_col1 {
#   background-color: #75030f;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_bd1d5_row0_col2 {
#   background-color: #8a0812;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_bd1d5_row0_col3 {
#   background-color: #a91016;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_bd1d5_row0_col4, #T_bd1d5_row1_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_bd1d5_row0_col5 {
#   background-color: #fff4ee;
#   color: #000000;
#   font-size: 0.8rem;
# }
# #T_bd1d5_row0_col6 {
#   background-color: #fed9c9;
#   color: #000000;
#   font-size: 0.8rem;
# }
# #T_bd1d5_row0_col7 {
#   background-color: #fa6648;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_bd1d5_row0_col8, #T_bd1d5_row1_col8 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-size: 0.8rem;
# }
# #T_bd1d5_row1_col1 {
#   background-color: #a81016;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_bd1d5_row1_col2 {
#   background-color: #960b13;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_bd1d5_row1_col3 {
#   background-color: #aa1016;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# #T_bd1d5_row1_col5 {
#   background-color: #fdd3c1;
#   color: #000000;
#   font-size: 0.8rem;
# }
# #T_bd1d5_row1_col6 {
#   background-color: #fdd1be;
#   color: #000000;
#   font-size: 0.8rem;
# }
# #T_bd1d5_row1_col7 {
#   background-color: #f85f43;
#   color: #f1f1f1;
#   font-size: 0.8rem;
# }
# </style>
# <table id="T_bd1d5">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Source</th>
#       <th id="T_bd1d5_level0_col0" class="col_heading level0 col0" colspan="3">AI21 Labs</th>
#       <th id="T_bd1d5_level0_col3" class="col_heading level0 col3" colspan="6">OpenAI</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" ></th>
#       <th id="T_bd1d5_level1_col0" class="col_heading level1 col0" >j1-grande</th>
#       <th id="T_bd1d5_level1_col1" class="col_heading level1 col1" >j1-grande-v2-beta</th>
#       <th id="T_bd1d5_level1_col2" class="col_heading level1 col2" >j1-jumbo</th>
#       <th id="T_bd1d5_level1_col3" class="col_heading level1 col3" >ada</th>
#       <th id="T_bd1d5_level1_col4" class="col_heading level1 col4" >davinci</th>
#       <th id="T_bd1d5_level1_col5" class="col_heading level1 col5" >text-ada-001</th>
#       <th id="T_bd1d5_level1_col6" class="col_heading level1 col6" >text-davinci-001</th>
#       <th id="T_bd1d5_level1_col7" class="col_heading level1 col7" >text-davinci-002</th>
#       <th id="T_bd1d5_level1_col8" class="col_heading level1 col8" >text-davinci-003</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >group</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bd1d5_level0_row0" class="row_heading level0 row0" >Female</th>
#       <td id="T_bd1d5_row0_col0" class="data row0 col0" >0.862</td>
#       <td id="T_bd1d5_row0_col1" class="data row0 col1" >0.861</td>
#       <td id="T_bd1d5_row0_col2" class="data row0 col2" >0.856</td>
#       <td id="T_bd1d5_row0_col3" class="data row0 col3" >0.848</td>
#       <td id="T_bd1d5_row0_col4" class="data row0 col4" >0.864</td>
#       <td id="T_bd1d5_row0_col5" class="data row0 col5" >0.750</td>
#       <td id="T_bd1d5_row0_col6" class="data row0 col6" >0.766</td>
#       <td id="T_bd1d5_row0_col7" class="data row0 col7" >0.807</td>
#       <td id="T_bd1d5_row0_col8" class="data row0 col8" >0.748</td>
#     </tr>
#     <tr>
#       <th id="T_bd1d5_level0_row1" class="row_heading level0 row1" >Male</th>
#       <td id="T_bd1d5_row1_col0" class="data row1 col0" >0.866</td>
#       <td id="T_bd1d5_row1_col1" class="data row1 col1" >0.850</td>
#       <td id="T_bd1d5_row1_col2" class="data row1 col2" >0.856</td>
#       <td id="T_bd1d5_row1_col3" class="data row1 col3" >0.849</td>
#       <td id="T_bd1d5_row1_col4" class="data row1 col4" >0.868</td>
#       <td id="T_bd1d5_row1_col5" class="data row1 col5" >0.757</td>
#       <td id="T_bd1d5_row1_col6" class="data row1 col6" >0.758</td>
#       <td id="T_bd1d5_row1_col7" class="data row1 col7" >0.806</td>
#       <td id="T_bd1d5_row1_col8" class="data row1 col8" >0.735</td>
#     </tr>
#   </tbody>
# </table>
